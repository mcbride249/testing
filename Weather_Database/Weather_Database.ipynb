# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 618

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | sorland
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | yulara
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | cartagena
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 1 | shizunai
# Processing Record 13 of Set 1 | portland
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | ahuimanu
# Processing Record 16 of Set 1 | nabire
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | srandakan
# Processing Record 20 of Set 1 | alofi
# Processing Record 21 of Set 1 | terme
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | broken hill
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 1 | sept-iles
# Processing Record 30 of Set 1 | fortuna
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | quatre cocos
# Processing Record 33 of Set 1 | hofn
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | tarakan
# Processing Record 36 of Set 1 | tautira
# Processing Record 37 of Set 1 | acuna
# City not found. Skipping...
# Processing Record 38 of Set 1 | christchurch
# Processing Record 39 of Set 1 | cabo san lucas
# Processing Record 40 of Set 1 | kuytun
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | arcachon
# Processing Record 43 of Set 1 | warrensburg
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | bengkulu
# Processing Record 46 of Set 1 | eydhafushi
# Processing Record 47 of Set 1 | tahta
# Processing Record 48 of Set 1 | rawah
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | lobito
# Processing Record 1 of Set 2 | luderitz
# Processing Record 2 of Set 2 | presidente epitacio
# Processing Record 3 of Set 2 | fort nelson
# Processing Record 4 of Set 2 | oum hadjer
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | constitucion
# Processing Record 7 of Set 2 | kolokani
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | nizwa
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | rawson
# Processing Record 13 of Set 2 | sadao
# Processing Record 14 of Set 2 | raudeberg
# Processing Record 15 of Set 2 | upernavik
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | boguchany
# Processing Record 18 of Set 2 | westport
# Processing Record 19 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 2 | lebanon
# Processing Record 21 of Set 2 | kaitangata
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | meulaboh
# Processing Record 24 of Set 2 | albany
# Processing Record 25 of Set 2 | yeletskiy
# City not found. Skipping...
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 2 | pisco
# Processing Record 29 of Set 2 | zhuhai
# Processing Record 30 of Set 2 | ulaangom
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | murgab
# Processing Record 33 of Set 2 | svencioneliai
# Processing Record 34 of Set 2 | khasan
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | luanda
# Processing Record 37 of Set 2 | camabatela
# Processing Record 38 of Set 2 | xining
# Processing Record 39 of Set 2 | auki
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | nikolskoye
# Processing Record 42 of Set 2 | kencong
# Processing Record 43 of Set 2 | guerrero negro
# Processing Record 44 of Set 2 | olafsvik
# Processing Record 45 of Set 2 | port hawkesbury
# Processing Record 46 of Set 2 | mount gambier
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | oistins
# Processing Record 49 of Set 2 | hede
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | saint george
# Processing Record 2 of Set 3 | daru
# Processing Record 3 of Set 3 | dhidhdhoo
# Processing Record 4 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 3 | praia
# Processing Record 6 of Set 3 | port alfred
# Processing Record 7 of Set 3 | provideniya
# Processing Record 8 of Set 3 | mount isa
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | pemba
# Processing Record 12 of Set 3 | namatanai
# Processing Record 13 of Set 3 | nassjo
# Processing Record 14 of Set 3 | burnie
# Processing Record 15 of Set 3 | boyolangu
# Processing Record 16 of Set 3 | grafton
# Processing Record 17 of Set 3 | mahajanga
# Processing Record 18 of Set 3 | odweyne
# Processing Record 19 of Set 3 | sucre
# Processing Record 20 of Set 3 | chapais
# Processing Record 21 of Set 3 | tabuk
# Processing Record 22 of Set 3 | chimoio
# Processing Record 23 of Set 3 | kuli
# Processing Record 24 of Set 3 | nuevo progreso
# Processing Record 25 of Set 3 | narsaq
# Processing Record 26 of Set 3 | smithers
# Processing Record 27 of Set 3 | lompoc
# Processing Record 28 of Set 3 | prince rupert
# Processing Record 29 of Set 3 | dikson
# Processing Record 30 of Set 3 | pokhara
# Processing Record 31 of Set 3 | bluff
# Processing Record 32 of Set 3 | taoudenni
# Processing Record 33 of Set 3 | carutapera
# Processing Record 34 of Set 3 | mimongo
# Processing Record 35 of Set 3 | ribeira grande
# Processing Record 36 of Set 3 | hualmay
# Processing Record 37 of Set 3 | seddon
# Processing Record 38 of Set 3 | pervomayskoye
# Processing Record 39 of Set 3 | puerto ayora
# Processing Record 40 of Set 3 | dubki
# Processing Record 41 of Set 3 | umba
# Processing Record 42 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 43 of Set 3 | mar del plata
# Processing Record 44 of Set 3 | nome
# Processing Record 45 of Set 3 | bilma
# Processing Record 46 of Set 3 | harper
# Processing Record 47 of Set 3 | salinas
# Processing Record 48 of Set 3 | krasnoselkup
# Processing Record 49 of Set 3 | east london
# Processing Record 50 of Set 3 | henties bay
# Processing Record 1 of Set 4 | yumen
# Processing Record 2 of Set 4 | padang
# Processing Record 3 of Set 4 | palauig
# Processing Record 4 of Set 4 | cayenne
# Processing Record 5 of Set 4 | kushiro
# Processing Record 6 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 7 of Set 4 | oranjemund
# Processing Record 8 of Set 4 | kousseri
# Processing Record 9 of Set 4 | sitka
# Processing Record 10 of Set 4 | hamilton
# Processing Record 11 of Set 4 | ilulissat
# Processing Record 12 of Set 4 | pietarsaari
# Processing Record 13 of Set 4 | pevek
# Processing Record 14 of Set 4 | armidale
# Processing Record 15 of Set 4 | chinchani
# Processing Record 16 of Set 4 | nanortalik
# Processing Record 17 of Set 4 | traverse city
# Processing Record 18 of Set 4 | ekibastuz
# Processing Record 19 of Set 4 | torbay
# Processing Record 20 of Set 4 | klaksvik
# Processing Record 21 of Set 4 | coihaique
# Processing Record 22 of Set 4 | mandiana
# Processing Record 23 of Set 4 | kargasok
# Processing Record 24 of Set 4 | copacabana
# Processing Record 25 of Set 4 | tabulbah
# City not found. Skipping...
# Processing Record 26 of Set 4 | catuday
# Processing Record 27 of Set 4 | cherskiy
# Processing Record 28 of Set 4 | atikokan
# Processing Record 29 of Set 4 | fonte boa
# Processing Record 30 of Set 4 | puerto penasco
# Processing Record 31 of Set 4 | saint-francois
# Processing Record 32 of Set 4 | san andres
# Processing Record 33 of Set 4 | isiro
# Processing Record 34 of Set 4 | coxim
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | sur
# Processing Record 37 of Set 4 | uribia
# Processing Record 38 of Set 4 | lexington park
# Processing Record 39 of Set 4 | puerto escondido
# Processing Record 40 of Set 4 | hounde
# Processing Record 41 of Set 4 | toungoo
# City not found. Skipping...
# Processing Record 42 of Set 4 | lebu
# Processing Record 43 of Set 4 | jumla
# Processing Record 44 of Set 4 | mana
# Processing Record 45 of Set 4 | port blair
# Processing Record 46 of Set 4 | bonfim
# Processing Record 47 of Set 4 | kutum
# Processing Record 48 of Set 4 | zhanaozen
# Processing Record 49 of Set 4 | norman wells
# Processing Record 50 of Set 4 | yarada
# Processing Record 1 of Set 5 | kharan
# Processing Record 2 of Set 5 | san policarpo
# Processing Record 3 of Set 5 | flinders
# Processing Record 4 of Set 5 | boca do acre
# Processing Record 5 of Set 5 | iqaluit
# Processing Record 6 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 5 | soyo
# Processing Record 8 of Set 5 | maragogi
# Processing Record 9 of Set 5 | broome
# Processing Record 10 of Set 5 | codrington
# Processing Record 11 of Set 5 | salima
# Processing Record 12 of Set 5 | port elizabeth
# Processing Record 13 of Set 5 | marystown
# Processing Record 14 of Set 5 | berestechko
# Processing Record 15 of Set 5 | vredendal
# Processing Record 16 of Set 5 | esperance
# Processing Record 17 of Set 5 | shache
# Processing Record 18 of Set 5 | deogarh
# Processing Record 19 of Set 5 | chokurdakh
# Processing Record 20 of Set 5 | rocha
# Processing Record 21 of Set 5 | lewiston
# Processing Record 22 of Set 5 | dharchula
# Processing Record 23 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 5 | wanning
# Processing Record 25 of Set 5 | banda aceh
# Processing Record 26 of Set 5 | balkanabat
# Processing Record 27 of Set 5 | kurud
# Processing Record 28 of Set 5 | vardo
# Processing Record 29 of Set 5 | filingue
# Processing Record 30 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 5 | pacific grove
# Processing Record 32 of Set 5 | ankang
# Processing Record 33 of Set 5 | clarksburg
# Processing Record 34 of Set 5 | mitu
# Processing Record 35 of Set 5 | faanui
# Processing Record 36 of Set 5 | mut
# Processing Record 37 of Set 5 | kalininsk
# Processing Record 38 of Set 5 | castro
# Processing Record 39 of Set 5 | ponta do sol
# Processing Record 40 of Set 5 | kolga
# Processing Record 41 of Set 5 | savonlinna
# Processing Record 42 of Set 5 | pangnirtung
# Processing Record 43 of Set 5 | bilibino
# Processing Record 44 of Set 5 | otane
# Processing Record 45 of Set 5 | boguchar
# Processing Record 46 of Set 5 | lorengau
# Processing Record 47 of Set 5 | kununurra
# Processing Record 48 of Set 5 | port hedland
# Processing Record 49 of Set 5 | enshi
# Processing Record 50 of Set 5 | millau
# Processing Record 1 of Set 6 | ulladulla
# Processing Record 2 of Set 6 | hasaki
# Processing Record 3 of Set 6 | piranshahr
# Processing Record 4 of Set 6 | zapadnaya dvina
# Processing Record 5 of Set 6 | laguna
# Processing Record 6 of Set 6 | roma
# Processing Record 7 of Set 6 | erzin
# Processing Record 8 of Set 6 | volos
# Processing Record 9 of Set 6 | mahebourg
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | mahanje
# Processing Record 12 of Set 6 | novopavlovka
# Processing Record 13 of Set 6 | sturgis
# Processing Record 14 of Set 6 | rio de janeiro
# Processing Record 15 of Set 6 | marsh harbour
# Processing Record 16 of Set 6 | sao filipe
# Processing Record 17 of Set 6 | carnarvon
# Processing Record 18 of Set 6 | pathein
# Processing Record 19 of Set 6 | mucurapo
# Processing Record 20 of Set 6 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 21 of Set 6 | tasiilaq
# Processing Record 22 of Set 6 | vostok
# Processing Record 23 of Set 6 | camacha
# Processing Record 24 of Set 6 | vihti
# Processing Record 25 of Set 6 | marawi
# Processing Record 26 of Set 6 | bereda
# Processing Record 27 of Set 6 | tual
# Processing Record 28 of Set 6 | mae sai
# Processing Record 29 of Set 6 | hoa binh
# Processing Record 30 of Set 6 | nuristan
# Processing Record 31 of Set 6 | sonoita
# Processing Record 32 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 33 of Set 6 | laranjeiras do sul
# Processing Record 34 of Set 6 | salalah
# Processing Record 35 of Set 6 | atzacan
# Processing Record 36 of Set 6 | homer
# Processing Record 37 of Set 6 | nantucket
# Processing Record 38 of Set 6 | kilindoni
# Processing Record 39 of Set 6 | tiznit
# Processing Record 40 of Set 6 | vestmanna
# Processing Record 41 of Set 6 | ostrovnoy
# Processing Record 42 of Set 6 | pyaozerskiy
# Processing Record 43 of Set 6 | alice springs
# Processing Record 44 of Set 6 | ust-ilimsk
# Processing Record 45 of Set 6 | san cristobal
# Processing Record 46 of Set 6 | tukrah
# Processing Record 47 of Set 6 | codajas
# Processing Record 48 of Set 6 | ust-maya
# Processing Record 49 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 6 | turukhansk
# Processing Record 1 of Set 7 | lazarev
# Processing Record 2 of Set 7 | brokopondo
# Processing Record 3 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 7 | finca corredor
# Processing Record 5 of Set 7 | kizukuri
# Processing Record 6 of Set 7 | rimouski
# Processing Record 7 of Set 7 | barcelos
# Processing Record 8 of Set 7 | balabac
# Processing Record 9 of Set 7 | charlestown
# Processing Record 10 of Set 7 | makakilo city
# Processing Record 11 of Set 7 | zyryanka
# Processing Record 12 of Set 7 | zamboanguita
# Processing Record 13 of Set 7 | clyde river
# Processing Record 14 of Set 7 | bodden town
# Processing Record 15 of Set 7 | hirado
# Processing Record 16 of Set 7 | dawlatabad
# Processing Record 17 of Set 7 | davila
# Processing Record 18 of Set 7 | tlaxiaco
# City not found. Skipping...
# Processing Record 19 of Set 7 | port-gentil
# Processing Record 20 of Set 7 | ugoofaaru
# Processing Record 21 of Set 7 | fare
# Processing Record 22 of Set 7 | airai
# Processing Record 23 of Set 7 | los llanos de aridane
# Processing Record 24 of Set 7 | yongan
# Processing Record 25 of Set 7 | port hardy
# Processing Record 26 of Set 7 | whitianga
# Processing Record 27 of Set 7 | kita
# Processing Record 28 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 7 | komsomolskiy
# Processing Record 30 of Set 7 | nichinan
# Processing Record 31 of Set 7 | labrea
# Processing Record 32 of Set 7 | jalu
# Processing Record 33 of Set 7 | marovoay
# Processing Record 34 of Set 7 | aljezur
# Processing Record 35 of Set 7 | amahai
# Processing Record 36 of Set 7 | mitsamiouli
# Processing Record 37 of Set 7 | tilhar
# Processing Record 38 of Set 7 | eyrarbakki
# Processing Record 39 of Set 7 | san carlos del zulia
# Processing Record 40 of Set 7 | abilene
# Processing Record 41 of Set 7 | hithadhoo
# Processing Record 42 of Set 7 | andujar
# Processing Record 43 of Set 7 | keetmanshoop
# Processing Record 44 of Set 7 | kruisfontein
# Processing Record 45 of Set 7 | fukue
# Processing Record 46 of Set 7 | chabahar
# Processing Record 47 of Set 7 | labuhan
# Processing Record 48 of Set 7 | necochea
# Processing Record 49 of Set 7 | at-bashi
# Processing Record 50 of Set 7 | pimentel
# Processing Record 1 of Set 8 | dingle
# Processing Record 2 of Set 8 | bambous virieux
# Processing Record 3 of Set 8 | souillac
# Processing Record 4 of Set 8 | tiarei
# Processing Record 5 of Set 8 | severo-kurilsk
# Processing Record 6 of Set 8 | kieta
# Processing Record 7 of Set 8 | ahipara
# Processing Record 8 of Set 8 | fort abbas
# Processing Record 9 of Set 8 | cidreira
# Processing Record 10 of Set 8 | calatayud
# Processing Record 11 of Set 8 | hambantota
# Processing Record 12 of Set 8 | lata
# Processing Record 13 of Set 8 | montepuez
# Processing Record 14 of Set 8 | seminole
# Processing Record 15 of Set 8 | mohiuddinagar
# City not found. Skipping...
# Processing Record 16 of Set 8 | revelstoke
# Processing Record 17 of Set 8 | ust-kuyga
# Processing Record 18 of Set 8 | hvide sande
# Processing Record 19 of Set 8 | guia de isora
# Processing Record 20 of Set 8 | kishi
# Processing Record 21 of Set 8 | bom jesus do itabapoana
# Processing Record 22 of Set 8 | khani
# Processing Record 23 of Set 8 | chapleau
# Processing Record 24 of Set 8 | northam
# Processing Record 25 of Set 8 | puerto baquerizo moreno
# Processing Record 26 of Set 8 | cabedelo
# Processing Record 27 of Set 8 | erzurum
# Processing Record 28 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 29 of Set 8 | khilok
# Processing Record 30 of Set 8 | dajabon
# Processing Record 31 of Set 8 | havoysund
# Processing Record 32 of Set 8 | jardim
# Processing Record 33 of Set 8 | manacapuru
# Processing Record 34 of Set 8 | touros
# Processing Record 35 of Set 8 | kodiak
# Processing Record 36 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 37 of Set 8 | kahului
# Processing Record 38 of Set 8 | olinda
# Processing Record 39 of Set 8 | porto velho
# Processing Record 40 of Set 8 | chongwe
# Processing Record 41 of Set 8 | dunedin
# Processing Record 42 of Set 8 | abu samrah
# Processing Record 43 of Set 8 | gat
# Processing Record 44 of Set 8 | astana
# Processing Record 45 of Set 8 | ucluelet
# Processing Record 46 of Set 8 | kulhudhuffushi
# Processing Record 47 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 8 | kapit
# Processing Record 49 of Set 8 | kavaratti
# Processing Record 50 of Set 8 | maldonado
# Processing Record 1 of Set 9 | nemuro
# Processing Record 2 of Set 9 | itaueira
# Processing Record 3 of Set 9 | nouadhibou
# Processing Record 4 of Set 9 | husavik
# Processing Record 5 of Set 9 | phangnga
# Processing Record 6 of Set 9 | lapua
# Processing Record 7 of Set 9 | sao joao da barra
# Processing Record 8 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 9 | doha
# Processing Record 10 of Set 9 | sakakah
# Processing Record 11 of Set 9 | muisne
# Processing Record 12 of Set 9 | ancud
# Processing Record 13 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 9 | selfoss
# Processing Record 15 of Set 9 | gambela
# Processing Record 16 of Set 9 | arona
# Processing Record 17 of Set 9 | bousso
# Processing Record 18 of Set 9 | kendari
# Processing Record 19 of Set 9 | aberdeen
# Processing Record 20 of Set 9 | borgarnes
# Processing Record 21 of Set 9 | fuyang
# Processing Record 22 of Set 9 | aklavik
# Processing Record 23 of Set 9 | verkhnevilyuysk
# Processing Record 24 of Set 9 | korem
# Processing Record 25 of Set 9 | saint-joseph
# Processing Record 26 of Set 9 | chicama
# Processing Record 27 of Set 9 | fenoarivo atsinanana
# Processing Record 28 of Set 9 | vestmannaeyjar
# Processing Record 29 of Set 9 | coquimbo
# Processing Record 30 of Set 9 | kristiinankaupunki
# Processing Record 31 of Set 9 | ochakiv
# Processing Record 32 of Set 9 | huasahuasi
# Processing Record 33 of Set 9 | lavrentiya
# Processing Record 34 of Set 9 | kitimat
# Processing Record 35 of Set 9 | belmonte
# Processing Record 36 of Set 9 | morondava
# Processing Record 37 of Set 9 | seoul
# Processing Record 38 of Set 9 | lipin bor
# Processing Record 39 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 9 | strezhevoy
# Processing Record 41 of Set 9 | iskateley
# Processing Record 42 of Set 9 | havre-saint-pierre
# Processing Record 43 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 9 | uptar
# Processing Record 45 of Set 9 | zima
# Processing Record 46 of Set 9 | gusau
# Processing Record 47 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 9 | saint-augustin
# Processing Record 49 of Set 9 | emmett
# Processing Record 50 of Set 9 | gorontalo
# Processing Record 1 of Set 10 | panaba
# Processing Record 2 of Set 10 | panguna
# Processing Record 3 of Set 10 | richards bay
# Processing Record 4 of Set 10 | alora
# Processing Record 5 of Set 10 | te anau
# Processing Record 6 of Set 10 | bathsheba
# Processing Record 7 of Set 10 | muros
# Processing Record 8 of Set 10 | abu dhabi
# Processing Record 9 of Set 10 | lipari
# Processing Record 10 of Set 10 | grindavik
# Processing Record 11 of Set 10 | arvin
# Processing Record 12 of Set 10 | khatanga
# Processing Record 13 of Set 10 | port-cartier
# Processing Record 14 of Set 10 | krasnyy chikoy
# Processing Record 15 of Set 10 | srednekolymsk
# Processing Record 16 of Set 10 | fontem
# Processing Record 17 of Set 10 | tonj
# Processing Record 18 of Set 10 | kaduqli
# Processing Record 19 of Set 10 | port lincoln
# Processing Record 20 of Set 10 | hovd
# Processing Record 21 of Set 10 | caravelas
# Processing Record 22 of Set 10 | akyab
# Processing Record 23 of Set 10 | katsuura
# Processing Record 24 of Set 10 | lasa
# Processing Record 25 of Set 10 | shubarshi
# Processing Record 26 of Set 10 | bitung
# Processing Record 27 of Set 10 | agadez
# Processing Record 28 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 29 of Set 10 | kupang
# Processing Record 30 of Set 10 | duma
# Processing Record 31 of Set 10 | rocky mountain house
# Processing Record 32 of Set 10 | gari
# Processing Record 33 of Set 10 | sobolevo
# Processing Record 34 of Set 10 | togur
# Processing Record 35 of Set 10 | hargeysa
# Processing Record 36 of Set 10 | aksarka
# Processing Record 37 of Set 10 | churachandpur
# Processing Record 38 of Set 10 | saint anthony
# Processing Record 39 of Set 10 | impfondo
# Processing Record 40 of Set 10 | pizarro
# Processing Record 41 of Set 10 | tuatapere
# Processing Record 42 of Set 10 | baykit
# Processing Record 43 of Set 10 | abnub
# Processing Record 44 of Set 10 | kharp
# Processing Record 45 of Set 10 | cap-aux-meules
# Processing Record 46 of Set 10 | kabanjahe
# Processing Record 47 of Set 10 | muzhi
# Processing Record 48 of Set 10 | karratha
# Processing Record 49 of Set 10 | bambanglipuro
# Processing Record 50 of Set 10 | pouebo
# Processing Record 1 of Set 11 | grand gaube
# Processing Record 2 of Set 11 | andenes
# Processing Record 3 of Set 11 | rize
# Processing Record 4 of Set 11 | russkaya polyana
# Processing Record 5 of Set 11 | chuy
# Processing Record 6 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 7 of Set 11 | pemberton
# Processing Record 8 of Set 11 | budhlada
# Processing Record 9 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 10 of Set 11 | puerto quijarro
# Processing Record 11 of Set 11 | amapa
# Processing Record 12 of Set 11 | manoharpur
# Processing Record 13 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 14 of Set 11 | tono
# Processing Record 15 of Set 11 | mecca
# Processing Record 16 of Set 11 | fianarantsoa
# Processing Record 17 of Set 11 | hare bay
# Processing Record 18 of Set 11 | sikandra rao
# Processing Record 19 of Set 11 | atambua
# Processing Record 20 of Set 11 | altamont
# Processing Record 21 of Set 11 | ouallam
# Processing Record 22 of Set 11 | maun
# Processing Record 23 of Set 11 | simbahan
# Processing Record 24 of Set 11 | lagoa
# Processing Record 25 of Set 11 | hami
# Processing Record 26 of Set 11 | izumo
# Processing Record 27 of Set 11 | berceni
# Processing Record 28 of Set 11 | naze
# Processing Record 29 of Set 11 | goderich
# Processing Record 30 of Set 11 | comodoro rivadavia
# Processing Record 31 of Set 11 | dieppe
# Processing Record 32 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 33 of Set 11 | san carlos
# Processing Record 34 of Set 11 | beloha
# Processing Record 35 of Set 11 | pangai
# Processing Record 36 of Set 11 | dinajpur
# Processing Record 37 of Set 11 | takoradi
# Processing Record 38 of Set 11 | isangel
# Processing Record 39 of Set 11 | deputatskiy
# Processing Record 40 of Set 11 | yelan-kolenovskiy
# Processing Record 41 of Set 11 | rio gallegos
# Processing Record 42 of Set 11 | hoopstad
# Processing Record 43 of Set 11 | milledgeville
# Processing Record 44 of Set 11 | statesboro
# Processing Record 45 of Set 11 | cambara
# Processing Record 46 of Set 11 | hailey
# Processing Record 47 of Set 11 | walvis bay
# Processing Record 48 of Set 11 | vila franca do campo
# Processing Record 49 of Set 11 | goundam
# Processing Record 50 of Set 11 | najran
# Processing Record 1 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 12 | crotone
# Processing Record 3 of Set 12 | egvekinot
# Processing Record 4 of Set 12 | takhtamygda
# Processing Record 5 of Set 12 | latung
# Processing Record 6 of Set 12 | oussouye
# Processing Record 7 of Set 12 | tuyen quang
# Processing Record 8 of Set 12 | gotsu
# Processing Record 9 of Set 12 | san ignacio
# Processing Record 10 of Set 12 | ishigaki
# Processing Record 11 of Set 12 | geraldton
# Processing Record 12 of Set 12 | itaqui
# Processing Record 13 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 14 of Set 12 | hohhot
# Processing Record 15 of Set 12 | klyuchi
# Processing Record 16 of Set 12 | yatou
# Processing Record 17 of Set 12 | wodonga
# Processing Record 18 of Set 12 | talnakh
# Processing Record 19 of Set 12 | vikhorevka
# Processing Record 20 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 12 | moscow
# Processing Record 22 of Set 12 | abalak
# Processing Record 23 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 25 of Set 12 | oktyabrskiy
# Processing Record 26 of Set 12 | rakaia
# Processing Record 27 of Set 12 | araouane
# Processing Record 28 of Set 12 | hobyo
# Processing Record 29 of Set 12 | vallenar
# Processing Record 30 of Set 12 | zharkent
# Processing Record 31 of Set 12 | agha jari
# City not found. Skipping...
# Processing Record 32 of Set 12 | atherton
# Processing Record 33 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 34 of Set 12 | nkhotakota
# Processing Record 35 of Set 12 | ruidoso
# Processing Record 36 of Set 12 | nagorsk
# Processing Record 37 of Set 12 | kaeo
# Processing Record 38 of Set 12 | cervo
# Processing Record 39 of Set 12 | terrace bay
# Processing Record 40 of Set 12 | talara
# Processing Record 41 of Set 12 | alexandria
# Processing Record 42 of Set 12 | shahrud
# Processing Record 43 of Set 12 | igarka
# Processing Record 44 of Set 12 | mandalgovi
# Processing Record 45 of Set 12 | kalmunai
# Processing Record 46 of Set 12 | manbij
# Processing Record 47 of Set 12 | fairbanks
# Processing Record 48 of Set 12 | south bend
# Processing Record 49 of Set 12 | tilichiki
# Processing Record 50 of Set 12 | thohoyandou
# Processing Record 1 of Set 13 | la ronge
# Processing Record 2 of Set 13 | poum
# Processing Record 3 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 4 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 13 | stokmarknes
# Processing Record 6 of Set 13 | muli
# Processing Record 7 of Set 13 | barbastro
# Processing Record 8 of Set 13 | vila do maio
# Processing Record 9 of Set 13 | nioro
# Processing Record 10 of Set 13 | kot putli
# City not found. Skipping...
# Processing Record 11 of Set 13 | zaozerne
# Processing Record 12 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 13 | praya
# Processing Record 14 of Set 13 | anloga
# Processing Record 15 of Set 13 | kollumerland
# City not found. Skipping...
# Processing Record 16 of Set 13 | port macquarie
# Processing Record 17 of Set 13 | sampit
# Processing Record 18 of Set 13 | loa janan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 80.19,
#   'Humidity': 85,
#   'Cloudiness': 93,
#   'Wind Speed': 4.85,
#   'Country': 'RE',
#   'Current Description': 'light rain'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 66.15,
#   'Humidity': 84,
#   'Cloudiness': 52,
#   'Wind Speed': 15.28,
#   'Country': 'ZA',
#   'Current Description': 'light rain'},
#  {'City': 'Sorland',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 34.3,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 13.29,
#   'Country': 'NO',
#   'Current Description': 'light rain'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 64.85,
#   'Humidity': 73,
#   'Cloudiness': 73,
#   'Wind Speed': 12.88,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 78.64,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 10.24,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 24.16,
#   'Country': 'SJ',
#   'Current Description': 'few clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 70.12,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Cartagena',
#   'Lat': 10.3997,
#   'Lng': -75.5144,
#   'Max Temp': 76.62,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'CO',
#   'Current Description': 'clear sky'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 57.06,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Shizunai',
#   'Lat': 42.3339,
#   'Lng': 142.3669,
#   'Max Temp': 36.95,
#   'Humidity': 75,
#   'Cloudiness': 4,
#   'Wind Speed': 6.11,
#   'Country': 'JP',
#   'Current Description': 'clear sky'},
#  {'City': 'Portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 60.75,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 51.91,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 32.21,
#   'Country': 'CL',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ahuimanu',
#   'Lat': 21.4447,
#   'Lng': -157.8378,
#   'Max Temp': 73.11,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Nabire',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 78.91,
#   'Humidity': 87,
#   'Cloudiness': 92,
#   'Wind Speed': 2.93,
#   'Country': 'ID',
#   'Current Description': 'moderate rain'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -9.89,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.8,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 1.92,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'Srandakan',
#   'Lat': -7.9386,
#   'Lng': 110.2506,
#   'Max Temp': 77.31,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 76.89,
#   'Humidity': 78,
#   'Cloudiness': 91,
#   'Wind Speed': 10.36,
#   'Country': 'NU',
#   'Current Description': 'light rain'},
#  {'City': 'Terme',
#   'Lat': 41.2092,
#   'Lng': 36.9739,
#   'Max Temp': 67.93,
#   'Humidity': 72,
#   'Cloudiness': 99,
#   'Wind Speed': 7.74,
#   'Country': 'TR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 74.46,
#   'Humidity': 57,
#   'Cloudiness': 71,
#   'Wind Speed': 20.89,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 56.7,
#   'Humidity': 98,
#   'Cloudiness': 6,
#   'Wind Speed': 0.72,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 69.51,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 73.36,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 7.49,
#   'Country': 'HK',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 31.32,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'light snow'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -8.36,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.6,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sept-Iles',
#   'Lat': 50.2001,
#   'Lng': -66.3821,
#   'Max Temp': 32.52,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 50.92,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 78.75,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'MY',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 84.31,
#   'Humidity': 68,
#   'Cloudiness': 21,
#   'Wind Speed': 9.42,
#   'Country': 'MU',
#   'Current Description': 'few clouds'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 29.61,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 5.88,
#   'Country': 'IS',
#   'Current Description': 'light snow'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 53.22,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'AR',
#   'Current Description': 'moderate rain'},
#  {'City': 'Tarakan',
#   'Lat': 3.3,
#   'Lng': 117.6333,
#   'Max Temp': 80.1,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'ID',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 78.82,
#   'Humidity': 81,
#   'Cloudiness': 84,
#   'Wind Speed': 17.76,
#   'Country': 'PF',
#   'Current Description': 'light rain'},
#  {'City': 'Christchurch',
#   'Lat': -43.5333,
#   'Lng': 172.6333,
#   'Max Temp': 57.4,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 72.07,
#   'Humidity': 74,
#   'Cloudiness': 99,
#   'Wind Speed': 7.87,
#   'Country': 'MX',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kuytun',
#   'Lat': 54.3419,
#   'Lng': 101.5036,
#   'Max Temp': 20.44,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 9.57,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 3.36,
#   'Humidity': 92,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Arcachon',
#   'Lat': 44.5875,
#   'Lng': -1.0519,
#   'Max Temp': 48.25,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'FR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Warrensburg',
#   'Lat': 38.7628,
#   'Lng': -93.7361,
#   'Max Temp': 37.89,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 41.59,
#   'Humidity': 97,
#   'Cloudiness': 34,
#   'Wind Speed': 0.74,
#   'Country': 'NZ',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 79.63,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 1.5,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Eydhafushi',
#   'Lat': 5.1033,
#   'Lng': 73.0708,
#   'Max Temp': 80.64,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 11.92,
#   'Country': 'MV',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tahta',
#   'Lat': 26.7693,
#   'Lng': 31.5021,
#   'Max Temp': 86.11,
#   'Humidity': 8,
#   'Cloudiness': 1,
#   'Wind Speed': 8.99,
#   'Country': 'EG',
#   'Current Description': 'clear sky'},
#  {'City': 'Rawah',
#   'Lat': 34.4816,
#   'Lng': 41.9093,
#   'Max Temp': 71.37,
#   'Humidity': 34,
#   'Cloudiness': 93,
#   'Wind Speed': 5.3,
#   'Country': 'IQ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 72.01,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Lobito',
#   'Lat': -12.3481,
#   'Lng': 13.5456,
#   'Max Temp': 76.06,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 4.07,
#   'Country': 'AO',
#   'Current Description': 'light rain'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 71.58,
#   'Humidity': 62,
#   'Cloudiness': 28,
#   'Wind Speed': 17.87,
#   'Country': 'NA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Presidente Epitacio',
#   'Lat': -21.7633,
#   'Lng': -52.1156,
#   'Max Temp': 84.51,
#   'Humidity': 36,
#   'Cloudiness': 3,
#   'Wind Speed': 5.32,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': -0.81,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'Oum Hadjer',
#   'Lat': 13.2954,
#   'Lng': 19.6966,
#   'Max Temp': 95.41,
#   'Humidity': 8,
#   'Cloudiness': 5,
#   'Wind Speed': 6.02,
#   'Country': 'TD',
#   'Current Description': 'clear sky'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 71.46,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 60.04,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 8.79,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Kolokani',
#   'Lat': 13.5728,
#   'Lng': -8.0339,
#   'Max Temp': 96.1,
#   'Humidity': 11,
#   'Cloudiness': 99,
#   'Wind Speed': 9.93,
#   'Country': 'ML',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 76.46,
#   'Humidity': 73,
#   'Cloudiness': 31,
#   'Wind Speed': 18.92,
#   'Country': 'PF',
#   'Current Description': 'light rain'},
#  {'City': 'Nizwa',
#   'Lat': 22.9333,
#   'Lng': 57.5333,
#   'Max Temp': 86.04,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 6.64,
#   'Country': 'OM',
#   'Current Description': 'clear sky'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 69.85,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'CK',
#   'Current Description': 'few clouds'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 64.8,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 8.37,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Sadao',
#   'Lat': 6.6388,
#   'Lng': 100.4234,
#   'Max Temp': 76.53,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.33,
#   'Country': 'TH',
#   'Current Description': 'moderate rain'},
#  {'City': 'Raudeberg',
#   'Lat': 61.9875,
#   'Lng': 5.1352,
#   'Max Temp': 27.27,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 7.81,
#   'Country': 'NO',
#   'Current Description': 'few clouds'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': -6.02,
#   'Humidity': 76,
#   'Cloudiness': 12,
#   'Wind Speed': 9.08,
#   'Country': 'GL',
#   'Current Description': 'few clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -5.13,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 15.03,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'Boguchany',
#   'Lat': 58.3814,
#   'Lng': 97.4531,
#   'Max Temp': 18.93,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 7.74,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Westport',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 35.42,
#   'Humidity': 64,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lebanon',
#   'Lat': 36.2081,
#   'Lng': -86.2911,
#   'Max Temp': 38.16,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 46.85,
#   'Humidity': 92,
#   'Cloudiness': 51,
#   'Wind Speed': 4.09,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Meulaboh',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 76.1,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.68,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 25.41,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 2.21,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 78.96,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'TO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 62.65,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'PE',
#   'Current Description': 'mist'},
#  {'City': 'Zhuhai',
#   'Lat': 22.2769,
#   'Lng': 113.5678,
#   'Max Temp': 73.11,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Ulaangom',
#   'Lat': 49.9811,
#   'Lng': 92.0667,
#   'Max Temp': 11.84,
#   'Humidity': 85,
#   'Cloudiness': 88,
#   'Wind Speed': 3.22,
#   'Country': 'MN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -7.35,
#   'Humidity': 95,
#   'Cloudiness': 85,
#   'Wind Speed': 5.41,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Murgab',
#   'Lat': 37.4966,
#   'Lng': 61.9714,
#   'Max Temp': 64.27,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'TM',
#   'Current Description': 'clear sky'},
#  {'City': 'Svencioneliai',
#   'Lat': 55.1667,
#   'Lng': 26,
#   'Max Temp': 33.98,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 5.68,
#   'Country': 'LT',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khasan',
#   'Lat': 42.4308,
#   'Lng': 130.6434,
#   'Max Temp': 36.27,
#   'Humidity': 62,
#   'Cloudiness': 90,
#   'Wind Speed': 3.83,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -3.98,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Country': 'US',
#   'Current Description': 'light snow'},
#  {'City': 'Luanda',
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp': 86,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'AO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Camabatela',
#   'Lat': -8.1881,
#   'Lng': 15.375,
#   'Max Temp': 73.27,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Country': 'AO',
#   'Current Description': 'moderate rain'},
#  {'City': 'Xining',
#   'Lat': 36.6167,
#   'Lng': 101.7667,
#   'Max Temp': 24.93,
#   'Humidity': 68,
#   'Cloudiness': 78,
#   'Wind Speed': 4.38,
#   'Country': 'CN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Auki',
#   'Lat': -8.7676,
#   'Lng': 160.7034,
#   'Max Temp': 77.65,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 4.52,
#   'Country': 'SB',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.46,
#   'Humidity': 80,
#   'Cloudiness': 72,
#   'Wind Speed': 14.58,
#   'Country': 'KI',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 26.49,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.58,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Kencong',
#   'Lat': -8.2833,
#   'Lng': 113.3667,
#   'Max Temp': 76.23,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.11,
#   'Country': 'ID',
#   'Current Description': 'moderate rain'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 62.49,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 3.83,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 39.29,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 18.45,
#   'Country': 'IS',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Hawkesbury',
#   'Lat': 45.6169,
#   'Lng': -61.3485,
#   'Max Temp': 35.19,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 57.11,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Oistins',
#   'Lat': 13.0667,
#   'Lng': -59.5333,
#   'Max Temp': 82.49,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'BB',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hede',
#   'Lat': 33.7681,
#   'Lng': 120.2517,
#   'Max Temp': 56.61,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 11.01,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.95,
#   'Humidity': 73,
#   'Cloudiness': 26,
#   'Wind Speed': 20.65,
#   'Country': 'PF',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 45.19,
#   'Humidity': 29,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Daru',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp': 81.14,
#   'Humidity': 77,
#   'Cloudiness': 77,
#   'Wind Speed': 4.7,
#   'Country': 'PG',
#   'Current Description': 'broken clouds'},
#  {'City': 'Dhidhdhoo',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 80.51,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 4.81,
#   'Country': 'MV',
#   'Current Description': 'moderate rain'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 10.99,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Praia',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 79.34,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 28.77,
#   'Country': 'CV',
#   'Current Description': 'few clouds'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 77.95,
#   'Humidity': 53,
#   'Cloudiness': 32,
#   'Wind Speed': 10.94,
#   'Country': 'ZA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': -5.82,
#   'Humidity': 78,
#   'Cloudiness': 6,
#   'Wind Speed': 4.5,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 85.77,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 65.93,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Pemba',
#   'Lat': -12.974,
#   'Lng': 40.5178,
#   'Max Temp': 81.21,
#   'Humidity': 64,
#   'Cloudiness': 94,
#   'Wind Speed': 15.68,
#   'Country': 'MZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 80.73,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 3.91,
#   'Country': 'PG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nassjo',
#   'Lat': 57.6531,
#   'Lng': 14.6968,
#   'Max Temp': 29.32,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 10.71,
#   'Country': 'SE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Burnie',
#   'Lat': -41.0667,
#   'Lng': 145.9167,
#   'Max Temp': 51.51,
#   'Humidity': 79,
#   'Cloudiness': 15,
#   'Wind Speed': 0.69,
#   'Country': 'AU',
#   'Current Description': 'few clouds'},
#  {'City': 'Boyolangu',
#   'Lat': -8.1181,
#   'Lng': 111.8935,
#   'Max Temp': 77.11,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.41,
#   'Country': 'ID',
#   'Current Description': 'light rain'},
#  {'City': 'Grafton',
#   'Lat': 42.207,
#   'Lng': -71.6856,
#   'Max Temp': 30.47,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mahajanga',
#   'Lat': -15.7167,
#   'Lng': 46.3167,
#   'Max Temp': 87.82,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Country': 'MG',
#   'Current Description': 'light rain'},
#  {'City': 'Odweyne',
#   'Lat': 9.4092,
#   'Lng': 45.064,
#   'Max Temp': 83.12,
#   'Humidity': 27,
#   'Cloudiness': 3,
#   'Wind Speed': 19.46,
#   'Country': 'SO',
#   'Current Description': 'clear sky'},
#  {'City': 'Sucre',
#   'Lat': -19.0333,
#   'Lng': -65.2627,
#   'Max Temp': 61.72,
#   'Humidity': 68,
#   'Cloudiness': 79,
#   'Wind Speed': 3.98,
#   'Country': 'BO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 13.78,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.52,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tabuk',
#   'Lat': 17.4189,
#   'Lng': 121.4443,
#   'Max Temp': 74.23,
#   'Humidity': 93,
#   'Cloudiness': 91,
#   'Wind Speed': 3.44,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chimoio',
#   'Lat': -19.1164,
#   'Lng': 33.4833,
#   'Max Temp': 78.66,
#   'Humidity': 50,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'MZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kuli',
#   'Lat': 42.0185,
#   'Lng': 47.2434,
#   'Max Temp': 41.34,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 1.5,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nuevo Progreso',
#   'Lat': 23.1667,
#   'Lng': -97.95,
#   'Max Temp': 62.83,
#   'Humidity': 96,
#   'Cloudiness': 28,
#   'Wind Speed': 6.22,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 39.42,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.62,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Smithers',
#   'Lat': 54.7804,
#   'Lng': -127.1743,
#   'Max Temp': 32.32,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Current Description': 'light rain'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 50.72,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Prince Rupert',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 44.69,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Current Description': 'moderate rain'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -12.59,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 10.71,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pokhara',
#   'Lat': 28.2333,
#   'Lng': 83.9833,
#   'Max Temp': 58.37,
#   'Humidity': 66,
#   'Cloudiness': 5,
#   'Wind Speed': 4.61,
#   'Country': 'NP',
#   'Current Description': 'clear sky'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 50.85,
#   'Humidity': 71,
#   'Cloudiness': 53,
#   'Wind Speed': 11.21,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 73.9,
#   'Humidity': 21,
#   'Cloudiness': 7,
#   'Wind Speed': 9.06,
#   'Country': 'ML',
#   'Current Description': 'clear sky'},
#  {'City': 'Carutapera',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 85.1,
#   'Humidity': 67,
#   'Cloudiness': 27,
#   'Wind Speed': 8.84,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mimongo',
#   'Lat': -1.6195,
#   'Lng': 11.6068,
#   'Max Temp': 88.84,
#   'Humidity': 43,
#   'Cloudiness': 87,
#   'Wind Speed': 4.07,
#   'Country': 'GA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 64.8,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'PT',
#   'Current Description': 'few clouds'},
#  {'City': 'Hualmay',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 66.31,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 8.08,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Seddon',
#   'Lat': -37.8068,
#   'Lng': 144.8916,
#   'Max Temp': 59.67,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Pervomayskoye',
#   'Lat': 43.919,
#   'Lng': 46.7102,
#   'Max Temp': 53.76,
#   'Humidity': 69,
#   'Cloudiness': 97,
#   'Wind Speed': 8.32,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 69.04,
#   'Humidity': 80,
#   'Cloudiness': 97,
#   'Wind Speed': 8.37,
#   'Country': 'EC',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dubki',
#   'Lat': 43.0225,
#   'Lng': 46.8372,
#   'Max Temp': 49.5,
#   'Humidity': 44,
#   'Cloudiness': 85,
#   'Wind Speed': 3.62,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Umba',
#   'Lat': 66.6871,
#   'Lng': 34.3429,
#   'Max Temp': 7.16,
#   'Humidity': 95,
#   'Cloudiness': 49,
#   'Wind Speed': 7.09,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 64.42,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'AR',
#   'Current Description': 'light rain'},
#  {'City': 'Nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': -16.53,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Bilma',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 89.85,
#   'Humidity': 10,
#   'Cloudiness': 80,
#   'Wind Speed': 13.62,
#   'Country': 'NE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Harper',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 84.04,
#   'Humidity': 69,
#   'Cloudiness': 65,
#   'Wind Speed': 6.67,
#   'Country': 'LR',
#   'Current Description': 'light rain'},
#  {'City': 'Salinas',
#   'Lat': 36.6777,
#   'Lng': -121.6555,
#   'Max Temp': 53.69,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.4667,
#   'Max Temp': -7.01,
#   'Humidity': 100,
#   'Cloudiness': 86,
#   'Wind Speed': 9.01,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 77.94,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Henties Bay',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 67.41,
#   'Humidity': 67,
#   'Cloudiness': 1,
#   'Wind Speed': 14.72,
#   'Country': 'NA',
#   'Current Description': 'clear sky'},
#  {'City': 'Yumen',
#   'Lat': 40.2833,
#   'Lng': 97.2,
#   'Max Temp': 22.39,
#   'Humidity': 38,
#   'Cloudiness': 59,
#   'Wind Speed': 21.59,
#   'Country': 'CN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 80.65,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 1.88,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Palauig',
#   'Lat': 15.435,
#   'Lng': 119.9045,
#   'Max Temp': 80.67,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 5.03,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 80.64,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'GF',
#   'Current Description': 'few clouds'},
#  {'City': 'Kushiro',
#   'Lat': 42.975,
#   'Lng': 144.3747,
#   'Max Temp': 27.55,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'JP',
#   'Current Description': 'few clouds'},
#  {'City': 'Oranjemund',
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp': 70.99,
#   'Humidity': 61,
#   'Cloudiness': 15,
#   'Wind Speed': 11.83,
#   'Country': 'NA',
#   'Current Description': 'few clouds'},
#  {'City': 'Kousseri',
#   'Lat': 12.0769,
#   'Lng': 15.0306,
#   'Max Temp': 98.56,
#   'Humidity': 8,
#   'Cloudiness': 54,
#   'Wind Speed': 10.36,
#   'Country': 'CM',
#   'Current Description': 'broken clouds'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 35.49,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'light snow'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 38.95,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 23.02,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pietarsaari',
#   'Lat': 63.65,
#   'Lng': 22.6833,
#   'Max Temp': 5.13,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.46,
#   'Country': 'FI',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -3.86,
#   'Humidity': 82,
#   'Cloudiness': 97,
#   'Wind Speed': 1.86,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Armidale',
#   'Lat': -30.5167,
#   'Lng': 151.65,
#   'Max Temp': 54.88,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chinchani',
#   'Lat': 19.8667,
#   'Lng': 72.7,
#   'Max Temp': 81.75,
#   'Humidity': 58,
#   'Cloudiness': 71,
#   'Wind Speed': 7.52,
#   'Country': 'IN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 38.48,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 14.81,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Traverse City',
#   'Lat': 44.7631,
#   'Lng': -85.6206,
#   'Max Temp': 34,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'light snow'},
#  {'City': 'Ekibastuz',
#   'Lat': 51.6667,
#   'Lng': 75.3667,
#   'Max Temp': 12.51,
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind Speed': 6.96,
#   'Country': 'KZ',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 45.37,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Current Description': 'few clouds'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 32.92,
#   'Humidity': 61,
#   'Cloudiness': 85,
#   'Wind Speed': 4.41,
#   'Country': 'FO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 49.95,
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'CL',
#   'Current Description': 'light rain'},
#  {'City': 'Mandiana',
#   'Lat': 10.6333,
#   'Lng': -8.6833,
#   'Max Temp': 94.86,
#   'Humidity': 21,
#   'Cloudiness': 75,
#   'Wind Speed': 7.49,
#   'Country': 'GN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kargasok',
#   'Lat': 59.0556,
#   'Lng': 80.8572,
#   'Max Temp': 28.6,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 12.91,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Copacabana',
#   'Lat': 6.3463,
#   'Lng': -75.5089,
#   'Max Temp': 63.03,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'CO',
#   'Current Description': 'haze'},
#  {'City': 'Catuday',
#   'Lat': 16.2923,
#   'Lng': 119.8062,
#   'Max Temp': 79.14,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 10.87,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -5.46,
#   'Humidity': 99,
#   'Cloudiness': 97,
#   'Wind Speed': 4.12,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Atikokan',
#   'Lat': 48.7555,
#   'Lng': -91.6216,
#   'Max Temp': 21.27,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 9.86,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fonte Boa',
#   'Lat': -2.4959,
#   'Lng': -66.2662,
#   'Max Temp': 78.87,
#   'Humidity': 82,
#   'Cloudiness': 86,
#   'Wind Speed': 2.42,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Penasco',
#   'Lat': 31.3167,
#   'Lng': -113.5333,
#   'Max Temp': 67.69,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 6.89,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Francois',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 36.84,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'FR',
#   'Current Description': 'light rain'},
#  {'City': 'San Andres',
#   'Lat': 12.5847,
#   'Lng': -81.7006,
#   'Max Temp': 80.96,
#   'Humidity': 78,
#   'Cloudiness': 55,
#   'Wind Speed': 17.78,
#   'Country': 'CO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Isiro',
#   'Lat': 2.7739,
#   'Lng': 27.616,
#   'Max Temp': 87.22,
#   'Humidity': 45,
#   'Cloudiness': 91,
#   'Wind Speed': 3.18,
#   'Country': 'CD',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coxim',
#   'Lat': -18.5067,
#   'Lng': -54.76,
#   'Max Temp': 86.4,
#   'Humidity': 60,
#   'Cloudiness': 19,
#   'Wind Speed': 8.84,
#   'Country': 'BR',
#   'Current Description': 'few clouds'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 34.16,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'light snow'},
#  {'City': 'Sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 80.94,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 6.35,
#   'Country': 'OM',
#   'Current Description': 'clear sky'},
#  {'City': 'Uribia',
#   'Lat': 11.7139,
#   'Lng': -72.266,
#   'Max Temp': 78.46,
#   'Humidity': 83,
#   'Cloudiness': 64,
#   'Wind Speed': 7.16,
#   'Country': 'CO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Lexington Park',
#   'Lat': 38.2668,
#   'Lng': -76.4538,
#   'Max Temp': 47.86,
#   'Humidity': 59,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 76.87,
#   'Humidity': 59,
#   'Cloudiness': 92,
#   'Wind Speed': 5.14,
#   'Country': 'MX',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hounde',
#   'Lat': 11.5,
#   'Lng': -3.5167,
#   'Max Temp': 96.31,
#   'Humidity': 10,
#   'Cloudiness': 95,
#   'Wind Speed': 8.46,
#   'Country': 'BF',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 53.33,
#   'Humidity': 66,
#   'Cloudiness': 3,
#   'Wind Speed': 14.54,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Jumla',
#   'Lat': 29.2747,
#   'Lng': 82.1838,
#   'Max Temp': 42.75,
#   'Humidity': 70,
#   'Cloudiness': 5,
#   'Wind Speed': 0.85,
#   'Country': 'NP',
#   'Current Description': 'clear sky'},
#  {'City': 'Mana',
#   'Lat': 5.6592,
#   'Lng': -53.7767,
#   'Max Temp': 81.75,
#   'Humidity': 74,
#   'Cloudiness': 32,
#   'Wind Speed': 10.04,
#   'Country': 'GF',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 81.66,
#   'Humidity': 76,
#   'Cloudiness': 55,
#   'Wind Speed': 9.86,
#   'Country': 'IN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bonfim',
#   'Lat': 3.0833,
#   'Lng': -59.95,
#   'Max Temp': 80.8,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 6.76,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kutum',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 84.69,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 9.44,
#   'Country': 'SD',
#   'Current Description': 'clear sky'},
#  {'City': 'Zhanaozen',
#   'Lat': 43.3,
#   'Lng': 52.8,
#   'Max Temp': 47.57,
#   'Humidity': 33,
#   'Cloudiness': 93,
#   'Wind Speed': 10.63,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -21.96,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'Yarada',
#   'Lat': 17.65,
#   'Lng': 83.2667,
#   'Max Temp': 80.92,
#   'Humidity': 61,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'IN',
#   'Current Description': 'haze'},
#  {'City': 'Kharan',
#   'Lat': 28.5833,
#   'Lng': 65.4167,
#   'Max Temp': 73.62,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 3.67,
#   'Country': 'PK',
#   'Current Description': 'clear sky'},
#  {'City': 'San Policarpo',
#   'Lat': 12.1791,
#   'Lng': 125.5072,
#   'Max Temp': 81.23,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 10.8,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 56.48,
#   'Humidity': 84,
#   'Cloudiness': 63,
#   'Wind Speed': 6.29,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Boca Do Acre',
#   'Lat': -8.7522,
#   'Lng': -67.3978,
#   'Max Temp': 74.66,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'BR',
#   'Current Description': 'light rain'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 24.53,
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'Soyo',
#   'Lat': -6.1349,
#   'Lng': 12.3689,
#   'Max Temp': 86.05,
#   'Humidity': 76,
#   'Cloudiness': 67,
#   'Wind Speed': 8.93,
#   'Country': 'AO',
#   'Current Description': 'light rain'},
#  {'City': 'Maragogi',
#   'Lat': -9.0122,
#   'Lng': -35.2225,
#   'Max Temp': 84.9,
#   'Humidity': 64,
#   'Cloudiness': 67,
#   'Wind Speed': 10.83,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 27.37,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'light snow'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 51.8,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 7.72,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Salima',
#   'Lat': -13.7804,
#   'Lng': 34.4587,
#   'Max Temp': 91.44,
#   'Humidity': 30,
#   'Cloudiness': 8,
#   'Wind Speed': 4.72,
#   'Country': 'MW',
#   'Current Description': 'clear sky'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 73.69,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Marystown',
#   'Lat': 47.1666,
#   'Lng': -55.1483,
#   'Max Temp': 45.75,
#   'Humidity': 86,
#   'Cloudiness': 8,
#   'Wind Speed': 15.23,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Berestechko',
#   'Lat': 50.3605,
#   'Lng': 25.1107,
#   'Max Temp': 42.35,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.67,
#   'Country': 'UA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vredendal',
#   'Lat': -31.6683,
#   'Lng': 18.5012,
#   'Max Temp': 72.37,
#   'Humidity': 64,
#   'Cloudiness': 93,
#   'Wind Speed': 16.44,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 82.24,
#   'Humidity': 40,
#   'Cloudiness': 63,
#   'Wind Speed': 16.06,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Shache',
#   'Lat': 38.4167,
#   'Lng': 77.2406,
#   'Max Temp': 35.01,
#   'Humidity': 31,
#   'Cloudiness': 14,
#   'Wind Speed': 2.1,
#   'Country': 'CN',
#   'Current Description': 'few clouds'},
#  {'City': 'Deogarh',
#   'Lat': 21.5333,
#   'Lng': 84.7333,
#   'Max Temp': 66.31,
#   'Humidity': 51,
#   'Cloudiness': 44,
#   'Wind Speed': 3.62,
#   'Country': 'IN',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -37.01,
#   'Humidity': 100,
#   'Cloudiness': 98,
#   'Wind Speed': 1.39,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 72.95,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 6.33,
#   'Country': 'UY',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lewiston',
#   'Lat': 44.1003,
#   'Lng': -70.2148,
#   'Max Temp': 25.43,
#   'Humidity': 85,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Dharchula',
#   'Lat': 29.85,
#   'Lng': 80.5333,
#   'Max Temp': 54.88,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind Speed': 3.38,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Wanning',
#   'Lat': 18.8003,
#   'Lng': 110.3967,
#   'Max Temp': 73.42,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 16.84,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 77.94,
#   'Humidity': 84,
#   'Cloudiness': 98,
#   'Wind Speed': 2.62,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Balkanabat',
#   'Lat': 39.5108,
#   'Lng': 54.3671,
#   'Max Temp': 60.58,
#   'Humidity': 34,
#   'Cloudiness': 87,
#   'Wind Speed': 2.64,
#   'Country': 'TM',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kurud',
#   'Lat': 20.8322,
#   'Lng': 81.7214,
#   'Max Temp': 80.58,
#   'Humidity': 42,
#   'Cloudiness': 56,
#   'Wind Speed': 5.48,
#   'Country': 'IN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 12.4,
#   'Humidity': 75,
#   'Cloudiness': 27,
#   'Wind Speed': 14.14,
#   'Country': 'NO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Filingue',
#   'Lat': 14.3521,
#   'Lng': 3.3168,
#   'Max Temp': 96.49,
#   'Humidity': 7,
#   'Cloudiness': 78,
#   'Wind Speed': 14.29,
#   'Country': 'NE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 53.28,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Ankang',
#   'Lat': 32.68,
#   'Lng': 109.0172,
#   'Max Temp': 52.92,
#   'Humidity': 55,
#   'Cloudiness': 9,
#   'Wind Speed': 0.96,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Clarksburg',
#   'Lat': 39.2807,
#   'Lng': -80.3445,
#   'Max Temp': 45.28,
#   'Humidity': 49,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mitu',
#   'Lat': 1.1983,
#   'Lng': -70.1733,
#   'Max Temp': 73.76,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 0.76,
#   'Country': 'CO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 80.64,
#   'Humidity': 74,
#   'Cloudiness': 44,
#   'Wind Speed': 9.82,
#   'Country': 'PF',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mut',
#   'Lat': 36.6439,
#   'Lng': 33.4389,
#   'Max Temp': 68.59,
#   'Humidity': 46,
#   'Cloudiness': 62,
#   'Wind Speed': 10.04,
#   'Country': 'TR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kalininsk',
#   'Lat': 51.5,
#   'Lng': 44.4758,
#   'Max Temp': 36.39,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 7.63,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 74.23,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 3.76,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 66.83,
#   'Humidity': 66,
#   'Cloudiness': 37,
#   'Wind Speed': 7.45,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kolga',
#   'Lat': 59.4867,
#   'Lng': 25.6192,
#   'Max Temp': 28.27,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 11.45,
#   'Country': 'EE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Savonlinna',
#   'Lat': 61.8699,
#   'Lng': 28.88,
#   'Max Temp': 19.45,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'FI',
#   'Current Description': 'clear sky'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 17.69,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 6.76,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -4.25,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.86,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Otane',
#   'Lat': -39.8833,
#   'Lng': 176.6333,
#   'Max Temp': 56.14,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Boguchar',
#   'Lat': 49.9358,
#   'Lng': 40.545,
#   'Max Temp': 50.18,
#   'Humidity': 78,
#   'Cloudiness': 94,
#   'Wind Speed': 5.57,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 81.63,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 4.03,
#   'Country': 'PG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 87.78,
#   'Humidity': 58,
#   'Cloudiness': 60,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Hedland',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 82.45,
#   'Humidity': 69,
#   'Cloudiness': 7,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Enshi',
#   'Lat': 30.3,
#   'Lng': 109.4833,
#   'Max Temp': 49.89,
#   'Humidity': 76,
#   'Cloudiness': 67,
#   'Wind Speed': 0.4,
#   'Country': 'CN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Millau',
#   'Lat': 44.0833,
#   'Lng': 2.9167,
#   'Max Temp': 33.93,
#   'Humidity': 95,
#   'Cloudiness': 97,
#   'Wind Speed': 14.18,
#   'Country': 'FR',
#   'Current Description': 'light snow'},
#  {'City': 'Ulladulla',
#   'Lat': -35.35,
#   'Lng': 150.4667,
#   'Max Temp': 56.3,
#   'Humidity': 83,
#   'Cloudiness': 84,
#   'Wind Speed': 3.98,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 45,
#   'Humidity': 47,
#   'Cloudiness': 4,
#   'Wind Speed': 15.52,
#   'Country': 'JP',
#   'Current Description': 'clear sky'},
#  {'City': 'Piranshahr',
#   'Lat': 36.701,
#   'Lng': 45.1413,
#   'Max Temp': 52.2,
#   'Humidity': 64,
#   'Cloudiness': 97,
#   'Wind Speed': 11.81,
#   'Country': 'IR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zapadnaya Dvina',
#   'Lat': 56.259,
#   'Lng': 32.0745,
#   'Max Temp': 34.92,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 7.61,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 59.5,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Roma',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp': 30.06,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Erzin',
#   'Lat': 36.9559,
#   'Lng': 36.2,
#   'Max Temp': 73.92,
#   'Humidity': 43,
#   'Cloudiness': 77,
#   'Wind Speed': 3.65,
#   'Country': 'TR',
#   'Current Description': 'broken clouds'},
# ...
#   'Max Temp': 42.75,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'JP',
#   'Current Description': 'clear sky'},
#  {'City': 'Berceni',
#   'Lat': 44.9333,
#   'Lng': 26.1167,
#   'Max Temp': 60.35,
#   'Humidity': 54,
#   'Cloudiness': 67,
#   'Wind Speed': 9.46,
#   'Country': 'RO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 63.59,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 19.73,
#   'Country': 'JP',
#   'Current Description': 'light rain'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 28.72,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 60.66,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 29.93,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Dieppe',
#   'Lat': 49.75,
#   'Lng': 1.1667,
#   'Max Temp': 41.18,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 16.15,
#   'Country': 'FR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Carlos',
#   'Lat': 9.6612,
#   'Lng': -68.5827,
#   'Max Temp': 77.07,
#   'Humidity': 78,
#   'Cloudiness': 18,
#   'Wind Speed': 2.26,
#   'Country': 'VE',
#   'Current Description': 'few clouds'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 77.88,
#   'Humidity': 34,
#   'Cloudiness': 1,
#   'Wind Speed': 17.9,
#   'Country': 'MG',
#   'Current Description': 'clear sky'},
#  {'City': 'Pangai',
#   'Lat': -19.8,
#   'Lng': -174.35,
#   'Max Temp': 79,
#   'Humidity': 77,
#   'Cloudiness': 96,
#   'Wind Speed': 24.02,
#   'Country': 'TO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dinajpur',
#   'Lat': 25.6272,
#   'Lng': 88.6386,
#   'Max Temp': 70.68,
#   'Humidity': 51,
#   'Cloudiness': 26,
#   'Wind Speed': 5.32,
#   'Country': 'BD',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Takoradi',
#   'Lat': 4.8845,
#   'Lng': -1.7554,
#   'Max Temp': 84.06,
#   'Humidity': 71,
#   'Cloudiness': 36,
#   'Wind Speed': 6.49,
#   'Country': 'GH',
#   'Current Description': 'light rain'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 77.74,
#   'Humidity': 86,
#   'Cloudiness': 85,
#   'Wind Speed': 8.48,
#   'Country': 'VU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -12.23,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yelan-Kolenovskiy',
#   'Lat': 51.1632,
#   'Lng': 41.151,
#   'Max Temp': 43.16,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.61,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rio Gallegos',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 57.25,
#   'Humidity': 35,
#   'Cloudiness': 40,
#   'Wind Speed': 18.41,
#   'Country': 'AR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hoopstad',
#   'Lat': -27.8327,
#   'Lng': 25.9083,
#   'Max Temp': 77.99,
#   'Humidity': 41,
#   'Cloudiness': 97,
#   'Wind Speed': 14.12,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Milledgeville',
#   'Lat': 33.0801,
#   'Lng': -83.2321,
#   'Max Temp': 42.19,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Statesboro',
#   'Lat': 32.4488,
#   'Lng': -81.7832,
#   'Max Temp': 41.14,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Cambara',
#   'Lat': -23.0464,
#   'Lng': -50.0736,
#   'Max Temp': 80.15,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Hailey',
#   'Lat': 43.5196,
#   'Lng': -114.3153,
#   'Max Temp': 31.86,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 76.15,
#   'Humidity': 50,
#   'Cloudiness': 11,
#   'Wind Speed': 13.8,
#   'Country': 'NA',
#   'Current Description': 'few clouds'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 61.21,
#   'Humidity': 66,
#   'Cloudiness': 89,
#   'Wind Speed': 5.73,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Goundam',
#   'Lat': 16.4145,
#   'Lng': -3.6708,
#   'Max Temp': 93.92,
#   'Humidity': 10,
#   'Cloudiness': 98,
#   'Wind Speed': 10.2,
#   'Country': 'ML',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Najran',
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Max Temp': 79.45,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 12.33,
#   'Country': 'SA',
#   'Current Description': 'clear sky'},
#  {'City': 'Crotone',
#   'Lat': 39.0851,
#   'Lng': 17.1178,
#   'Max Temp': 61.11,
#   'Humidity': 73,
#   'Cloudiness': 96,
#   'Wind Speed': 29.8,
#   'Country': 'IT',
#   'Current Description': 'light rain'},
#  {'City': 'Egvekinot',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': -9.6,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 0.38,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Takhtamygda',
#   'Lat': 54.1,
#   'Lng': 123.5667,
#   'Max Temp': 2.34,
#   'Humidity': 89,
#   'Cloudiness': 85,
#   'Wind Speed': 3.04,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Latung',
#   'Lat': 5.5,
#   'Lng': 120.8833,
#   'Max Temp': 83.68,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 6.64,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Oussouye',
#   'Lat': 12.485,
#   'Lng': -16.5469,
#   'Max Temp': 87.98,
#   'Humidity': 23,
#   'Cloudiness': 30,
#   'Wind Speed': 11.68,
#   'Country': 'SN',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tuyen Quang',
#   'Lat': 21.8233,
#   'Lng': 105.2181,
#   'Max Temp': 67.14,
#   'Humidity': 69,
#   'Cloudiness': 7,
#   'Wind Speed': 0.54,
#   'Country': 'VN',
#   'Current Description': 'clear sky'},
#  {'City': 'Gotsu',
#   'Lat': 35,
#   'Lng': 132.2167,
#   'Max Temp': 48.47,
#   'Humidity': 63,
#   'Cloudiness': 69,
#   'Wind Speed': 5.32,
#   'Country': 'JP',
#   'Current Description': 'broken clouds'},
#  {'City': 'San Ignacio',
#   'Lat': 17.1561,
#   'Lng': -89.0714,
#   'Max Temp': 66.34,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'BZ',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ishigaki',
#   'Lat': 24.3448,
#   'Lng': 124.1572,
#   'Max Temp': 71.73,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 24.16,
#   'Country': 'JP',
#   'Current Description': 'shower rain'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 72.01,
#   'Humidity': 78,
#   'Cloudiness': 2,
#   'Wind Speed': 13.8,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Itaqui',
#   'Lat': -29.1253,
#   'Lng': -56.5531,
#   'Max Temp': 68.23,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 4.74,
#   'Country': 'BR',
#   'Current Description': 'moderate rain'},
#  {'City': 'Hohhot',
#   'Lat': 40.8106,
#   'Lng': 111.6522,
#   'Max Temp': 37.69,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 15.66,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Klyuchi',
#   'Lat': 52.2667,
#   'Lng': 79.1667,
#   'Max Temp': 16.65,
#   'Humidity': 88,
#   'Cloudiness': 31,
#   'Wind Speed': 7.4,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Yatou',
#   'Lat': 37.15,
#   'Lng': 122.3833,
#   'Max Temp': 49.3,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 6.15,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Wodonga',
#   'Lat': -36.1167,
#   'Lng': 146.8833,
#   'Max Temp': 64.4,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -11.34,
#   'Humidity': 98,
#   'Cloudiness': 99,
#   'Wind Speed': 3.89,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vikhorevka',
#   'Lat': 56.1201,
#   'Lng': 101.1636,
#   'Max Temp': 15.39,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 9.4,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Moscow',
#   'Lat': 55.7522,
#   'Lng': 37.6156,
#   'Max Temp': 39.63,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 9.26,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Abalak',
#   'Lat': 58.1286,
#   'Lng': 68.5944,
#   'Max Temp': 21.65,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 7.07,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Oktyabrskiy',
#   'Lat': 54.4815,
#   'Lng': 53.471,
#   'Max Temp': 27.63,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 15.21,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rakaia',
#   'Lat': -43.75,
#   'Lng': 172.0167,
#   'Max Temp': 56.21,
#   'Humidity': 99,
#   'Cloudiness': 67,
#   'Wind Speed': 6.71,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 82.56,
#   'Humidity': 19,
#   'Cloudiness': 86,
#   'Wind Speed': 14.36,
#   'Country': 'ML',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hobyo',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 83.82,
#   'Humidity': 69,
#   'Cloudiness': 66,
#   'Wind Speed': 17.29,
#   'Country': 'SO',
#   'Current Description': 'light rain'},
#  {'City': 'Vallenar',
#   'Lat': -28.5708,
#   'Lng': -70.7581,
#   'Max Temp': 71.82,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Zharkent',
#   'Lat': 44.1628,
#   'Lng': 80,
#   'Max Temp': 32.95,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 2.37,
#   'Country': 'KZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Atherton',
#   'Lat': 53.5237,
#   'Lng': -2.4935,
#   'Max Temp': 40.32,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 3.4,
#   'Country': 'GB',
#   'Current Description': 'snow'},
#  {'City': 'Nkhotakota',
#   'Lat': -12.9274,
#   'Lng': 34.2961,
#   'Max Temp': 82.78,
#   'Humidity': 49,
#   'Cloudiness': 23,
#   'Wind Speed': 4.65,
#   'Country': 'MW',
#   'Current Description': 'few clouds'},
#  {'City': 'Ruidoso',
#   'Lat': 33.3317,
#   'Lng': -105.673,
#   'Max Temp': 32.14,
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Nagorsk',
#   'Lat': 59.3172,
#   'Lng': 50.8078,
#   'Max Temp': 28.9,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 10.71,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Kaeo',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 59.36,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.73,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cervo',
#   'Lat': 43.6702,
#   'Lng': -7.4101,
#   'Max Temp': 51.84,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 15.08,
#   'Country': 'ES',
#   'Current Description': 'light rain'},
#  {'City': 'Terrace Bay',
#   'Lat': 48.7834,
#   'Lng': -87.1,
#   'Max Temp': 26.22,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 11.9,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Talara',
#   'Lat': -4.5772,
#   'Lng': -81.2719,
#   'Max Temp': 67.41,
#   'Humidity': 78,
#   'Cloudiness': 96,
#   'Wind Speed': 11.92,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Alexandria',
#   'Lat': 31.2156,
#   'Lng': 29.9553,
#   'Max Temp': 82.94,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'EG',
#   'Current Description': 'clear sky'},
#  {'City': 'Shahrud',
#   'Lat': 36.4182,
#   'Lng': 54.9763,
#   'Max Temp': 52.38,
#   'Humidity': 40,
#   'Cloudiness': 99,
#   'Wind Speed': 8.01,
#   'Country': 'IR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Igarka',
#   'Lat': 67.4667,
#   'Lng': 86.5833,
#   'Max Temp': 0.54,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.09,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mandalgovi',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 14.56,
#   'Humidity': 48,
#   'Cloudiness': 55,
#   'Wind Speed': 7.27,
#   'Country': 'MN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kalmunai',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 80.26,
#   'Humidity': 83,
#   'Cloudiness': 97,
#   'Wind Speed': 8.7,
#   'Country': 'LK',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Manbij',
#   'Lat': 36.5281,
#   'Lng': 37.9549,
#   'Max Temp': 63.37,
#   'Humidity': 45,
#   'Cloudiness': 61,
#   'Wind Speed': 6.22,
#   'Country': 'SY',
#   'Current Description': 'broken clouds'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': -23.46,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.81,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'South Bend',
#   'Lat': 41.6834,
#   'Lng': -86.25,
#   'Max Temp': 36.45,
#   'Humidity': 78,
#   'Cloudiness': 85,
#   'Wind Speed': 12.06,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tilichiki',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp': 15.75,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 7.76,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thohoyandou',
#   'Lat': -22.9456,
#   'Lng': 30.485,
#   'Max Temp': 87.13,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 5.39,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'La Ronge',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 15.39,
#   'Humidity': 93,
#   'Cloudiness': 95,
#   'Wind Speed': 7.54,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 80.62,
#   'Humidity': 75,
#   'Cloudiness': 31,
#   'Wind Speed': 7,
#   'Country': 'NC',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Stokmarknes',
#   'Lat': 68.5646,
#   'Lng': 14.9108,
#   'Max Temp': 26.64,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 9.31,
#   'Country': 'NO',
#   'Current Description': 'light snow'},
#  {'City': 'Muli',
#   'Lat': 2.9167,
#   'Lng': 73.5667,
#   'Max Temp': 82.44,
#   'Humidity': 70,
#   'Cloudiness': 92,
#   'Wind Speed': 15.03,
#   'Country': 'MV',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barbastro',
#   'Lat': 42.0356,
#   'Lng': 0.1269,
#   'Max Temp': 44.78,
#   'Humidity': 43,
#   'Cloudiness': 21,
#   'Wind Speed': 17.11,
#   'Country': 'ES',
#   'Current Description': 'few clouds'},
#  {'City': 'Vila Do Maio',
#   'Lat': 15.1333,
#   'Lng': -23.2167,
#   'Max Temp': 76.1,
#   'Humidity': 74,
#   'Cloudiness': 91,
#   'Wind Speed': 22.57,
#   'Country': 'CV',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nioro',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 94.59,
#   'Humidity': 18,
#   'Cloudiness': 11,
#   'Wind Speed': 12.33,
#   'Country': 'GM',
#   'Current Description': 'few clouds'},
#  {'City': 'Zaozerne',
#   'Lat': 45.1582,
#   'Lng': 33.2787,
#   'Max Temp': 55.04,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 7.58,
#   'Country': 'UA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Praya',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 79.34,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 28.77,
#   'Country': 'CV',
#   'Current Description': 'few clouds'},
#  {'City': 'Anloga',
#   'Lat': 5.7947,
#   'Lng': 0.8973,
#   'Max Temp': 85.03,
#   'Humidity': 70,
#   'Cloudiness': 70,
#   'Wind Speed': 9.15,
#   'Country': 'GH',
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Macquarie',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 64.17,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sampit',
#   'Lat': -2.5333,
#   'Lng': 112.95,
#   'Max Temp': 71.8,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.2,
#   'Country': 'ID',
#   'Current Description': 'light rain'},
#  {'City': 'Loa Janan',
#   'Lat': -0.583,
#   'Lng': 117.095,
#   'Max Temp': 76.64,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'ID',
#   'Current Description': 'light rain'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Philippe -21.3585   55.7679     80.19        85          93
# 1        Hermanus -34.4187   19.2345     66.15        84          52
# 2         Sorland  67.6670   12.6934     34.30        61         100
# 3       Busselton -33.6500  115.3333     64.85        73          73
# 4          Yulara -25.2406  130.9889     78.64        19           0
# 5    Longyearbyen  78.2186   15.6401     10.24        48          20
# 6           Kapaa  22.0752 -159.3190     70.12        78           1
# 7       Cartagena  10.3997  -75.5144     76.62        94           0
# 8          Hobart -42.8794  147.3294     57.06        77          40
# 9        Shizunai  42.3339  142.3669     36.95        75           4
#
#    Wind Speed Country Current Description
# 0        4.85      RE          light rain
# 1       15.28      ZA          light rain
# 2       13.29      NO          light rain
# 3       12.88      AU       broken clouds
# 4        6.91      AU           clear sky
# 5       24.16      SJ          few clouds
# 6        6.91      US           clear sky
# 7        4.61      CO           clear sky
# 8        4.61      AU    scattered clouds
# 9        6.11      JP           clear sky

# %%
len(city_data)
# Out:
# 568

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Saint-Philippe      RE -21.3585   55.7679     80.19        85
# 1          Hermanus      ZA -34.4187   19.2345     66.15        84
# 2           Sorland      NO  67.6670   12.6934     34.30        61
# 3         Busselton      AU -33.6500  115.3333     64.85        73
# 4            Yulara      AU -25.2406  130.9889     78.64        19
# ..              ...     ...      ...       ...       ...       ...
# 563           Praya      CV  14.9215  -23.5087     79.34        61
# 564          Anloga      GH   5.7947    0.8973     85.03        70
# 565  Port Macquarie      AU -31.4333  152.9167     64.17        84
# 566          Sampit      ID  -2.5333  112.9500     71.80        98
# 567       Loa Janan      ID  -0.5830  117.0950     76.64        90
#
#      Cloudiness  Wind Speed Current Description
# 0            93        4.85          light rain
# 1            52       15.28          light rain
# 2           100       13.29          light rain
# 3            73       12.88       broken clouds
# 4             0        6.91           clear sky
# ..          ...         ...                 ...
# 563          20       28.77          few clouds
# 564          70        9.15       broken clouds
# 565          99        8.05     overcast clouds
# 566         100        3.20          light rain
# 567         100        2.51          light rain
#
# [568 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
